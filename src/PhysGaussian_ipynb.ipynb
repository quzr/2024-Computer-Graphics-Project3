# %% [markdown]
# ## Environment Setup

# %%
# %cd /content

# clone PhysGaussian repo
# !git clone --recurse-submodules https://github.com/XPandora/PhysGaussian.git
# %cd PhysGaussian

# install dependencies of Gaussian Splatting
# !pip install -e gaussian-splatting/submodules/diff-gaussian-rasterization/
# !pip install -e gaussian-splatting/submodules/simple-knn/

# install addtional dependencies of PhysGaussian
# !pip install plyfile==1.0.3 PyMCubes==0.1.4 pymeshlab==2023.12.post1 taichi==1.5.0 warp_lang==0.10.1
# Out:
# /content
# Cloning into 'PhysGaussian'...
# remote: Enumerating objects: 470, done.
# remote: Counting objects: 100% (175/175), done.
# remote: Compressing objects: 100% (135/135), done.
# remote: Total 470 (delta 44), reused 163 (delta 35), pack-reused 295
# Receiving objects: 100% (470/470), 255.31 MiB | 16.53 MiB/s, done.
# Resolving deltas: 100% (44/44), done.
# Submodule 'gaussian-splatting' (https://github.com/graphdeco-inria/gaussian-splatting) registered for path 'gaussian-splatting'
# Cloning into '/content/PhysGaussian/gaussian-splatting'...
# remote: Enumerating objects: 728, done.
# remote: Counting objects: 100% (240/240), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 728 (delta 205), reused 202 (delta 201), pack-reused 488
# Receiving objects: 100% (728/728), 2.12 MiB | 28.63 MiB/s, done.
# Resolving deltas: 100% (425/425), done.
# Submodule path 'gaussian-splatting': checked out 'd9fad7b3450bf4bd29316315032d57157e23a515'
# Submodule 'SIBR_viewers' (https://gitlab.inria.fr/sibr/sibr_core.git) registered for path 'gaussian-splatting/SIBR_viewers'
# Submodule 'submodules/diff-gaussian-rasterization' (https://github.com/graphdeco-inria/diff-gaussian-rasterization) registered for path 'gaussian-splatting/submodules/diff-gaussian-rasterization'
# Submodule 'submodules/simple-knn' (https://gitlab.inria.fr/bkerbl/simple-knn.git) registered for path 'gaussian-splatting/submodules/simple-knn'
# Cloning into '/content/PhysGaussian/gaussian-splatting/SIBR_viewers'...
# remote: Enumerating objects: 3133, done.
# remote: Counting objects: 100% (162/162), done.
# remote: Compressing objects: 100% (162/162), done.
# remote: Total 3133 (delta 71), reused 0 (delta 0), pack-reused 2971
# Receiving objects: 100% (3133/3133), 9.91 MiB | 6.38 MiB/s, done.
# Resolving deltas: 100% (1939/1939), done.
# Cloning into '/content/PhysGaussian/gaussian-splatting/submodules/diff-gaussian-rasterization'...
# remote: Enumerating objects: 222, done.
# remote: Counting objects: 100% (130/130), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 222 (delta 110), reused 89 (delta 89), pack-reused 92
# Receiving objects: 100% (222/222), 73.58 KiB | 9.20 MiB/s, done.
# Resolving deltas: 100% (141/141), done.
# Cloning into '/content/PhysGaussian/gaussian-splatting/submodules/simple-knn'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 26 (delta 11), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (26/26), 7.03 KiB | 7.03 MiB/s, done.
# Resolving deltas: 100% (11/11), done.
# Submodule path 'gaussian-splatting/SIBR_viewers': checked out '4ae964a267cd7a844d9766563cf9d0b500131a22'
# Submodule path 'gaussian-splatting/submodules/diff-gaussian-rasterization': checked out '59f5f77e3ddbac3ed9db93ec2cfe99ed6c5d121d'
# Submodule 'third_party/glm' (https://github.com/g-truc/glm.git) registered for path 'gaussian-splatting/submodules/diff-gaussian-rasterization/third_party/glm'
# Cloning into '/content/PhysGaussian/gaussian-splatting/submodules/diff-gaussian-rasterization/third_party/glm'...
# remote: Enumerating objects: 59595, done.
# remote: Counting objects: 100% (2592/2592), done.
# remote: Compressing objects: 100% (758/758), done.
# remote: Total 59595 (delta 1928), reused 2320 (delta 1798), pack-reused 57003
# Receiving objects: 100% (59595/59595), 71.40 MiB | 15.25 MiB/s, done.
# Resolving deltas: 100% (44962/44962), done.
# Submodule path 'gaussian-splatting/submodules/diff-gaussian-rasterization/third_party/glm': checked out '5c46b9c07008ae65cb81ab79cd677ecc1934b903'
# Submodule path 'gaussian-splatting/submodules/simple-knn': checked out '44f764299fa305faf6ec5ebd99939e0508331503'
# /content/PhysGaussian
# Obtaining file:///content/PhysGaussian/gaussian-splatting/submodules/diff-gaussian-rasterization
#   Preparing metadata (setup.py) ... done
# Installing collected packages: diff-gaussian-rasterization
#   Running setup.py develop for diff-gaussian-rasterization
# Successfully installed diff-gaussian-rasterization-0.0.0
# Obtaining file:///content/PhysGaussian/gaussian-splatting/submodules/simple-knn
#   Preparing metadata (setup.py) ... done
# Installing collected packages: simple-knn
#   Running setup.py develop for simple-knn
# Successfully installed simple-knn-0.0.0
# Collecting plyfile==1.0.3
#   Downloading plyfile-1.0.3-py3-none-any.whl (23 kB)
# Collecting PyMCubes==0.1.4
#   Downloading PyMCubes-0.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (274 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.3/274.3 kB 9.5 MB/s eta 0:00:00
# Collecting pymeshlab==2023.12.post1
#   Downloading pymeshlab-2023.12.post1-cp310-cp310-manylinux_2_31_x86_64.whl (98.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.0/98.0 MB 9.3 MB/s eta 0:00:00
# Collecting taichi==1.5.0
#   Downloading taichi-1.5.0-cp310-cp310-manylinux_2_27_x86_64.whl (51.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 MB 2.7 MB/s eta 0:00:00
# Collecting warp_lang==0.10.1
#   Downloading warp_lang-0.10.1-py3-none-manylinux2014_x86_64.whl (52.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from plyfile==1.0.3) (1.25.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from PyMCubes==0.1.4) (1.11.4)
# Collecting colorama (from taichi==1.5.0)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting dill (from taichi==1.5.0)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 20.3 MB/s eta 0:00:00
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from taichi==1.5.0) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->taichi==1.5.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->taichi==1.5.0) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->taichi==1.5.0) (0.1.2)
# Installing collected packages: warp_lang, pymeshlab, plyfile, dill, colorama, PyMCubes, taichi
# Successfully installed PyMCubes-0.1.4 colorama-0.4.6 dill-0.3.8 plyfile-1.0.3 pymeshlab-2023.12.post1 taichi-1.5.0 warp_lang-0.10.1

# %% [markdown]
# ## Quick Start (ficus)

# %%
# download pretrained Gaussian Splatting model of ficus
# !pip install gdown
# !bash download_sample_model.sh
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.7.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.13.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From (original): https://drive.google.com/uc?id=1zic8PNxUsYESyrVZ8Ywy-FxpmQ01PGpe
# From (redirected): https://drive.google.com/uc?id=1zic8PNxUsYESyrVZ8Ywy-FxpmQ01PGpe&confirm=t&uuid=c6350801-6f35-4139-a4f6-6ed8e8e0483d
# To: /content/PhysGaussian/model/ficus_whitebg-trained.zip
# 100% 395M/395M [00:05<00:00, 76.4MB/s]
# Archive:  ./model/ficus_whitebg-trained.zip
#    creating: ./model/ficus_whitebg-trained/
#   inflating: ./model/ficus_whitebg-trained/cfg_args
#   inflating: ./model/ficus_whitebg-trained/input.ply
#   inflating: ./model/ficus_whitebg-trained/cameras.json
#   inflating: ./model/ficus_whitebg-trained/chkpnt7000.pth
#   inflating: ./model/ficus_whitebg-trained/chkpnt30000.pth
#    creating: ./model/ficus_whitebg-trained/point_cloud/
#    creating: ./model/ficus_whitebg-trained/point_cloud/iteration_7000/
#   inflating: ./model/ficus_whitebg-trained/point_cloud/iteration_7000/point_cloud.ply
#    creating: ./model/ficus_whitebg-trained/point_cloud/iteration_30000/
#   inflating: ./model/ficus_whitebg-trained/point_cloud/iteration_30000/point_cloud.ply
#    creating: ./model/ficus_whitebg-trained/point_cloud/iteration_60000/
#   inflating: ./model/ficus_whitebg-trained/point_cloud/iteration_60000/point_cloud.ply

# %%
# simulate GS models!
# !python gs_simulation.py --model_path ./model/ficus_whitebg-trained/ --output_path output --config ./config/ficus_config.json --render_img --compile_video --white_bg
# Out:
# [Taichi] version 1.5.0, llvm 15.0.4, commit 7b885c28, linux, python 3.10.12
# Warp 0.10.1 initialized:
#    CUDA Toolkit: 11.5, Driver: 12.2
#    Devices:
#      "cpu"    | x86_64
#      "cuda:0" | Tesla T4 (sm_75)
#    Kernel cache: /root/.cache/warp/0.10.1
# [Taichi] Starting on arch=cuda
# Loading scene config...
# Loading gaussians...
# Initializing scene and pre-processing...
# Initializing MPM solver and setting up boundary conditions...
# Module warp_utils load on device 'cuda:0' took 489.28 ms
# Particles initialized from torch data.
# Total particles:  171553
# Module mpm_utils load on device 'cuda:0' took 43687.76 ms
#   0% 0/125 [00:00<?, ?it/s]Module mpm_solver_warp.mpm_solver_warp load on device 'cuda:0' took 452.15 ms
# 100% 125/125 [01:56<00:00,  1.07it/s]
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from 'output/%04d.png':
#   Duration: 00:00:05.00, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 800x800, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5819d6720900] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5819d6720900] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x5819d6720900] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'output/output.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 800x800, q=2-31, 25 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  125 fps= 33 q=-1.0 Lsize=     444kB time=00:00:04.88 bitrate= 745.8kbits/s speed=1.31x
# video:442kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.450222%
# [libx264 @ 0x5819d6720900] frame I:1     Avg QP:18.53  size: 16583
# [libx264 @ 0x5819d6720900] frame P:75    Avg QP:23.05  size:  5296
# [libx264 @ 0x5819d6720900] frame B:49    Avg QP:28.37  size:   784
# [libx264 @ 0x5819d6720900] consecutive B-frames: 36.8% 30.4%  7.2% 25.6%
# [libx264 @ 0x5819d6720900] mb I  I16..4: 25.2% 65.5%  9.3%
# [libx264 @ 0x5819d6720900] mb P  I16..4:  0.1%  0.5%  0.1%  P16..4:  5.0%  5.4%  6.0%  0.0%  0.0%    skip:83.0%
# [libx264 @ 0x5819d6720900] mb B  I16..4:  0.0%  0.1%  0.0%  B16..8:  7.4%  1.4%  0.4%  direct: 0.4%  skip:90.2%  L0:19.7% L1:35.7% BI:44.5%
# [libx264 @ 0x5819d6720900] 8x8 transform intra:68.8% inter:37.3%
# [libx264 @ 0x5819d6720900] coded y,uvDC,uvAC intra: 14.1% 15.5% 13.7% inter: 5.2% 4.7% 2.6%
# [libx264 @ 0x5819d6720900] i16 v,h,dc,p: 86%  4% 10%  0%
# [libx264 @ 0x5819d6720900] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 29%  5% 61%  1%  1%  1%  1%  1%  1%
# [libx264 @ 0x5819d6720900] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 15% 18%  7%  8%  9%  8%  9%  8%
# [libx264 @ 0x5819d6720900] i8c dc,h,v,p: 81%  6% 12%  2%
# [libx264 @ 0x5819d6720900] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5819d6720900] ref P L0: 79.0% 17.0%  2.9%  1.1%
# [libx264 @ 0x5819d6720900] ref B L0: 95.7%  3.8%  0.5%
# [libx264 @ 0x5819d6720900] ref B L1: 99.4%  0.6%
# [libx264 @ 0x5819d6720900] kb/s:723.52

# %%
from IPython.display import HTML
from base64 import b64encode

# preview simulation results
video_name = 'output/output.mp4'
data_url = "data:video/mp4;base64," + b64encode(open(video_name, 'rb').read()).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
